# %% [markdown]
# # 📘 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 0. Pandas 자료 구조 이해하기

# %%
#Series Class : 1차원 - 인덱스(index) + 값(value)
#DataFrame Class : 2차원 - 표와 같은 형태

# %% [markdown]
# ![image.png](attachment:1192acdd-b064-4ed8-8f60-5381164dfc23.png)
# ![image.png](attachment:f47faad0-15ce-4840-9ef0-715666ccce6e.png)

# %% [markdown]
# # 🧱 1. Series 생성 및 이름 지정

# %%
s1 = pd.Series([10, 20, 30], name="점수")
display(s1)
# Out:
# 0    10
# 1    20
# 2    30
# Name: 점수, dtype: int64

# %%
# ✏️ 연습: 영희, 철수, 민수의 이름 리스트를 Series로 만들고 s2에 저장하고, 시리즈 이름을 '이름'으로 설정해보세요.
#["영희", "철수", "민수"]
# Out:
# 0    영희
# 1    철수
# 2    민수
# Name: 이름, dtype: object

# %% [markdown]
# # 🧱 2. DataFrame 생성

# %%
#  딕셔너리 기반
data = {
    "이름": ["영희", "철수", "민수"],
    "나이": [20, 21, 19],
    "성별": ["F", "M", "M"]
}
df = pd.DataFrame(data)
df
# Out:
#    이름  나이 성별
# 0  영희  20  F
# 1  철수  21  M
# 2  민수  19  M

# %%
# list 기반 
data = [["영희", 20, "F"],
        ["철수", 21, "M"],
       ["민수", 19, "M"]]
df = pd.DataFrame(data, columns= ["이름","나이","성별"])
display(df)
print(df.columns)  # 컬럼명 확인
print(df.index)    # 인덱스명 확인
# Out:
#    이름  나이 성별
# 0  영희  20  F
# 1  철수  21  M
# 2  민수  19  M
# Index(['이름', '나이', '성별'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)

# %%
# ✏️ 연습 - 아래 리스트 데이터를 담은 하나의 데이터 프레임을 생성하시오.
# name = ["영희", "철수", "민수"]
# python_score = [90, 65, 75]
# db_score = [100, 85, 65]

# 딕셔너리로 데이터 구성


# 데이터프레임 생성


# 출력
# Out:
#    이름  파이썬  데이터베이스
# 0  영희   90     100
# 1  철수   65      85
# 2  민수   75      65

# %% [markdown]
# # 🧱 3. Series 병합해서 DataFrame 만들기

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# Name: 점수, dtype: int64

# %%
s2
# Out:
# 0    영희
# 1    철수
# 2    민수
# Name: 이름, dtype: object

# %%
# 🎈 연습
# s1과 s2 병합해서 데이터 프레임으로 구성
# 병합하는 함수는 ? 
df2 =
# Out:
#    점수  이름
# 0  10  영희
# 1  20  철수
# 2  30  민수

# %% [markdown]
# # ✅ 4. 데이터 접근
#  - pandas에서 제일 즐거운 부분💙
#  - 데이터 인덱싱 , 슬라이싱
#      - 위치 기반 접근
#      - 조건 기반 접근

# %%
df
# Out:
#    이름  나이 성별
# 0  영희  20  F
# 1  철수  21  M
# 2  민수  19  M

# %% [markdown]
# - 위치기반 데이터 접근

# %%
# 위치 기반 - 행 접근(슬라이싱!)
display(df[0:1])
display(df[1:])
# Out:
#    이름  나이 성별
# 0  영희  20  F
#    이름  나이 성별
# 1  철수  21  M
# 2  민수  19  M

# %%
# 위치 기반 - 행 접근( loc, iloc 개념 사용하기)
display(df.loc[0])
display(df.loc[1:])
display(df.loc[1:2])
print()
display(df.iloc[0])
display(df.iloc[1:])
display(df.iloc[1:2]) #loc랑 차이 비교하기
# Out:
# 이름    영희
# 나이    20
# 성별     F
# Name: 0, dtype: object
#    이름  나이 성별
# 1  철수  21  M
# 2  민수  19  M
#    이름  나이 성별
# 1  철수  21  M
# 2  민수  19  M
# 이름    영희
# 나이    20
# 성별     F
# Name: 0, dtype: object
#    이름  나이 성별
# 1  철수  21  M
# 2  민수  19  M
#    이름  나이 성별
# 1  철수  21  M

# %%
# 위치 기반 - 열 접근(인덱싱1)
display(df['이름'])
display(df[['이름']])
display(df[['이름', '성별']])
# Out:
# 0    영희
# 1    철수
# 2    민수
# Name: 이름, dtype: object
#    이름
# 0  영희
# 1  철수
# 2  민수
#    이름 성별
# 0  영희  F
# 1  철수  M
# 2  민수  M

# %%
# 위치 기반 - 열 접근 (loc, iloc 개념 사용하기)
print('--loc, 라벨 이름 위치 기반--')
display(df.loc[:,"이름"])
display(df.loc[:,["이름"]])
display(df.loc[:,["이름","성별"]])
display(df.loc[:,"이름":"성별"])
print('--iloc, 인덱스 위치 기반--')
display(df.iloc[:,0])
display(df.iloc[:,[0]])
display(df.iloc[:,[0,2]])
display(df.iloc[:,0:2]) # loc랑 차이 비교
# Out:
# --loc, 라벨 이름 위치 기반--
# 0    영희
# 1    철수
# 2    민수
# Name: 이름, dtype: object
#    이름
# 0  영희
# 1  철수
# 2  민수
#    이름 성별
# 0  영희  F
# 1  철수  M
# 2  민수  M
#    이름  나이 성별
# 0  영희  20  F
# 1  철수  21  M
# 2  민수  19  M
# --iloc, 인덱스 위치 기반--
# 0    영희
# 1    철수
# 2    민수
# Name: 이름, dtype: object
#    이름
# 0  영희
# 1  철수
# 2  민수
#    이름 성별
# 0  영희  F
# 1  철수  M
# 2  민수  M
#    이름  나이
# 0  영희  20
# 1  철수  21
# 2  민수  19

# %%
# 위치기반 - 행, 열 동시 접근(loc, iloc 사용하기)
display(df.loc[2,'이름'])
display(df.iloc[2,0])
# Out:
# '민수'
# '민수'

# %%
display(df.loc[[0,2],'이름'])
print()
display(df.iloc[[0,2],0])
print()
display(df.iloc[0:2:2,0])
# Out:
# 0    영희
# 2    민수
# Name: 이름, dtype: object
# 0    영희
# 2    민수
# Name: 이름, dtype: object
# 0    영희
# Name: 이름, dtype: object

# %%
df2
# Out:
#    점수  이름
# 0  10  영희
# 1  20  철수
# 2  30  민수

# %%
# 🎈 연습 - 위에 있는 df2를 기준으로 인덱싱 연습하기
## 1.   '철수'의 행을 출력해보세요.

## 2. 전체 이름(영희, 철수, 민수)만 출력해보세요. 출력형태는 시리즈입니다.


## 3. 전체 이름(영희, 철수, 민수)만 출력해보세요. 출력형태는 데이터프레임입니다.


## 4. 인덱스 번호 첫 번째와 두 번째 행만 선택해보세요. 


## 3. 인덱스 번호 첫 번째와 두 번째 행의 점수만 선택해보세요.
# Out:
#    점수  이름
# 0  10  영희
# 1  20  철수
# 2  30  민수

# %% [markdown]
# - 조건기반 데이터 접근

# %%
df
# Out:
#    이름  나이 성별
# 0  영희  20  F
# 1  철수  21  M
# 2  민수  19  M

# %%
df[df["성별"] =="M"]
# Out:
#    이름  나이 성별
# 1  철수  21  M
# 2  민수  19  M

# %%
df[df["나이"] >= 30]
# Out:
# Empty DataFrame
# Columns: [이름, 나이, 성별]
# Index: []

# %%
df[df["나이"] >= 20]
# Out:
#    이름  나이 성별
# 0  영희  20  F
# 1  철수  21  M

# %%
# 조건, 위치 하이브리드 데이터 접근 
df.loc[df["나이"] >= 20, "이름"]
# Out:
# 0    영희
# 1    철수
# Name: 이름, dtype: object

# %%
df2
# Out:
#    점수  이름
# 0  10  영희
# 1  20  철수
# 2  30  민수

# %%
# 🎈 연습- df2 데이터 접근하기
## 1. 점수가 15점 이상인 학생 정보 출력하기

## 2. 이름이 '철수'인 행만 출력하기

## 3. 이름이 '철수'인 행의 점수만 출력하기

## 4. 불리언 조건을 연결하자! 
## 점수가 20 이상이고 이름이 '민수'가 아닌 사람 출력하기
## 논리를 연결할떄에는 불리언 인덱싱 진행지 비트연산자 연결(&, \)

# %% [markdown]
# # 🧮 5. 컬럼 추가, 수정, 삭제

# %%
df["지역"] = ["서울", "부산", "대구"]  # 새 컬럼 추가
display(df)
df["나이"] = df["나이"] + 1           # 컬럼 값 수정
display(df)
df = df.drop(columns=["성별"])        # 컬럼 삭제
display(df)
# Out:
#    이름  나이 성별  지역
# 0  영희  20  F  서울
# 1  철수  21  M  부산
# 2  민수  19  M  대구
#    이름  나이 성별  지역
# 0  영희  21  F  서울
# 1  철수  22  M  부산
# 2  민수  20  M  대구
#    이름  나이  지역
# 0  영희  21  서울
# 1  철수  22  부산
# 2  민수  20  대구

# %%
df2
# Out:
#    점수  이름
# 0  10  영희
# 1  20  철수
# 2  30  민수

# %%
# 🎈 연습 - df2 데이터에 컬럼 추가, 수정, 삭제하기
## 1. 성별 컬럼명으로 ["여자", "남자", "남자"] 추가하기

## 2. 영희의 나이를 30살로 수정하기

## 3. 점수 컬럼을 삭제한다면?

# %%
# assign 함수 (추가로 알아보기)
# -새로운 컬럼을 추가하거나
# -기존 컬럼을 기반으로 계산한 결과를 붙이고 싶을 때 사용하는 함수
# - 체이닝에 적합

# %%
df
# Out:
#    이름  나이 성별
# 0  영희  20  F
# 1  철수  21  M
# 2  민수  19  M

# %%
df = df.assign(내년나이 = df["나이"] + 1)
df
# Out:
#    이름  나이 성별  내년나이
# 0  영희  20  F    21
# 1  철수  21  M    22
# 2  민수  19  M    20

# %%
# 연습 - 현재 나이를 기준으로 '5년후나이' 컬럼 추가하기

# %% [markdown]
# # 6. 데이터 이해하는 주요함수

# %%
df
df.dtypes
# Out:
# 이름    object
# 나이     int64
# 지역    object
# dtype: object

# %%
df.head()
# Out:
#    이름  나이  지역
# 0  영희  21  서울
# 1  철수  22  부산
# 2  민수  20  대구

# %%
df.describe()
# Out:
#          나이
# count   3.0
# mean   21.0
# std     1.0
# min    20.0
# 25%    20.5
# 50%    21.0
# 75%    21.5
# max    22.0

# %%
df.isnull().sum()
# Out:
# 이름    0
# 나이    0
# 지역    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      3 non-null      object
#  1   나이      3 non-null      int64
#  2   지역      3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df['이름'].value_counts()
# Out:
# 영희    1
# 철수    1
# 민수    1
# Name: 이름, dtype: int64

# %%
# 위 함수 연습은 아래 파일 불러온 이후에 적용해보자!

# %% [markdown]
# # 📂 6. CSV 불러오기 & 저장하기
# ## 예제 CSV 파일이 있는 경우 아래 경로 수정하여 실행
#
# ### 불러오기
# - df_csv = pd.read_csv("sample.csv")
# - print(df_csv)
#
# ### 저장하기
# - df_csv.to_csv("saved_sample.csv", index=False)
#
# ### 현재 작업 경로 확인하기
# -
# print("현재 작업 디렉토리:", os.getcwd())

# %%
# ✏️ 상대경로 vs 절대경로로 파일 불러오기를 실습해보세요.
# 상대경로: sample.csv
# 절대경로: C:/Users/YourName/Desktop/sample.csv

# %%
# 연습
## 1. 첨부된 exam.csv 파일을 불러와서 data 변수에 담기
data = 
## 2. 데이터 크기확인

## 3. 데이터 타입확인

## 4. 데이터 기술통계량 확인

## 5. 데이터 정보 확인

## 6. 데이터 결측치 여부 확인

## 7. nclass 컬럼 내에 클래스 등장 빈도수 세기

# %%
data
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# # 🔨 7. 사용자 정의함수 연결해서 데이터 처리하기

# %%
data.iloc[:,2:5].dtypes
# Out:
# math       int64
# english    int64
# science    int64
# dtype: object

# %%
def get_grade(x):
    grade = ""
    avg = x.mean()
    if avg >= 90:
        grade = "A"
    elif avg >= 80:
        grade= "B"
    elif avg >= 70:
        grade = "C"
    elif avg >= 60:
        grade = "D"
    else:
        grade = "F"
    return grade

data["grade"] = data.iloc[:,2:5].apply(get_grade, axis=1)
data
# Out:
#     id  nclass  math  english  science grade
# 0    1       1    50       98       50     D
# 1    2       1    60       97       60     C
# 2    3       1    45       86       78     D
# 3    4       1    30       98       58     D
# 4    5       2    25       80       65     F
# 5    6       2    50       89       98     C
# 6    7       2    80       90       45     C
# 7    8       2    90       78       25     D
# 8    9       3    20       98       15     F
# 9   10       3    50       98       45     D
# 10  11       3    65       65       65     D
# 11  12       3    45       85       32     F
# 12  13       4    46       98       65     D
# 13  14       4    48       87       12     F
# 14  15       4    75       56       78     D
# 15  16       4    58       98       65     C
# 16  17       5    65       68       98     C
# 17  18       5    80       78       90     B
# 18  19       5    89       68       87     B
# 19  20       5    78       83       58     C

# %%
# 🥁 연습 - grade 컬럼 값을 통해 A~C면 'Pass'이고, D~F는 'Fail'값으로 변환한 데이터를 담은 check 컬럼을 생성하시오.
## 1. 사용자 정의함수 생성
# Out:
#     id  nclass  math  english  science grade check
# 0    1       1    50       98       50     D  Fail
# 1    2       1    60       97       60     C  Pass
# 2    3       1    45       86       78     D  Fail
# 3    4       1    30       98       58     D  Fail
# 4    5       2    25       80       65     F  Fail
# 5    6       2    50       89       98     C  Pass
# 6    7       2    80       90       45     C  Pass
# 7    8       2    90       78       25     D  Fail
# 8    9       3    20       98       15     F  Fail
# 9   10       3    50       98       45     D  Fail
# 10  11       3    65       65       65     D  Fail
# 11  12       3    45       85       32     F  Fail
# 12  13       4    46       98       65     D  Fail
# 13  14       4    48       87       12     F  Fail
# 14  15       4    75       56       78     D  Fail
# 15  16       4    58       98       65     C  Pass
# 16  17       5    65       68       98     C  Pass
# ...

# %%
## 2. 대상 데이터를 접근하여 apply함수로 위 1번 사용자 정의함수 연결해보기
# Out:
#     id  nclass  math  english  science grade check
# 0    1       1    50       98       50     D  Fail
# 1    2       1    60       97       60     C  Pass
# 2    3       1    45       86       78     D  Fail
# 3    4       1    30       98       58     D  Fail
# 4    5       2    25       80       65     F  Fail
# 5    6       2    50       89       98     C  Pass
# 6    7       2    80       90       45     C  Pass
# 7    8       2    90       78       25     D  Fail
# 8    9       3    20       98       15     F  Fail
# 9   10       3    50       98       45     D  Fail
# 10  11       3    65       65       65     D  Fail
# 11  12       3    45       85       32     F  Fail
# 12  13       4    46       98       65     D  Fail
# 13  14       4    48       87       12     F  Fail
# 14  15       4    75       56       78     D  Fail
# 15  16       4    58       98       65     C  Pass
# 16  17       5    65       68       98     C  Pass
# ...

# %% [markdown]
# # ✨ 8. 목적에 맞게 데이터 통계 확인하기

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
list(data.groupby(['nclass']))
# Out:
# [(1,
#      id  nclass  math  english  science grade check
#   0   1       1    50       98       50     D  Fail
#   1   2       1    60       97       60     C  Pass
#   2   3       1    45       86       78     D  Fail
#   3   4       1    30       98       58     D  Fail),
#  (2,
#      id  nclass  math  english  science grade check
#   4   5       2    25       80       65     F  Fail
#   5   6       2    50       89       98     C  Pass
#   6   7       2    80       90       45     C  Pass
#   7   8       2    90       78       25     D  Fail),
#  (3,
#       id  nclass  math  english  science grade check
#   8    9       3    20       98       15     F  Fail
#   9   10       3    50       98       45     D  Fail
#   10  11       3    65       65       65     D  Fail
#   11  12       3    45       85       32     F  Fail),
#  (4,
#       id  nclass  math  english  science grade check
#   12  13       4    46       98       65     D  Fail
# ...

# %%
# 반별 수학 성적 평균 점수 구하기 (groupby)
data.groupby(['nclass'])['math'].mean()
# Out:
# nclass
# 1    46.25
# 2    61.25
# 3    45.00
# 4    56.75
# 5    78.00
# Name: math, dtype: float64

# %%
data.groupby(['nclass']).agg(class_math_mean = ('math', 'mean'))
# Out:
#         class_math_mean
# nclass
# 1                 46.25
# 2                 61.25
# 3                 45.00
# 4                 56.75
# 5                 78.00

# %%
# 🥁 연습 - 반별 영어 성적 평균 점수 구하기 (groupby)
# Out:
# nclass
# 1    94.75
# 2    84.25
# 3    86.50
# 4    84.75
# 5    74.25
# Name: english, dtype: float64

# %%
# 🥁 연습 - grade별 반(nclass) 인원 수 확인하기 (조합 분석)

# %%
# 🥁 연습 - 최종 data 변수에 담긴 데이터프레임을 csv로 저장하기
