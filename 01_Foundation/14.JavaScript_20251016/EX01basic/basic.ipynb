# %% [markdown]
# # 1.javascript 역사
#  - ![image.png](attachment:image.png)
#  - 아이폰에서 ActiveX를 사용하지 않겠다. 선언. why? 베터리 일체형으로 만들었다 => nodejs의 언어가 javascript 기반이었다. 그래서 흥했다.
#
#
#
#  - 장점 : 통신이 빠르다 (talk app에 강점)
#  - 단점 : 대량의 작업시 부적합하다
#  - 단점 : 디버깅이 어렵다. 문자와 숫자가 빼진다. 문자와 숫자가 더해진다. 콘솔창에서 잡아내기 어렵다
#
#
#  - nodejs, React, anguler, view
#  - runtime environment => nodejs

# %% [markdown]
# - 자료형
# - ![image.png](attachment:image.png)
# - undifiend => exception error
# - null => blank(Value 존재 有)
#
# - ![image-2.png](attachment:image-2.png)
