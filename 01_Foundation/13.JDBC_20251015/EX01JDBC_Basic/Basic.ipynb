# %% [markdown]
# # 1. JDBC(java + DataBase + Connectivity)
# ## 1.1. JDBC(Java DataBase Connectivity)필요성
# - 관계형 DB에 저장된 Data를 접근 및 조작할 수 있게 하는 인터페이스 기반 자바 API
# - java에서 oracle과 mySQL등의 연결을 쉽게 하기 위해서 Interface를 만들었다.
#
# - ![image.png](attachment:image.png)
#
# - 돼지코(converter)와 같은 기능을 한다.
# - 5단계로 진행된다
#     - 드라이버 로딩
#     - 데이터베이스 연결
#     - Query 전송 (query문)
#     - 결과를 이용한 작업처리
#     - 자원반납
#
#
# - path 설정해줘야한다.
#
# - oraclexe> app > oracle> product> 11.2.0 > serer> jdbc> lib > ojdbc6.jar(가장 잘 맞는다고함.)
# - ![image-2.png](attachment:image-2.png)
#
# ## 1.2. DBMS(DataBase Management System)
