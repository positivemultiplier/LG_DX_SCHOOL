# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc("font", family="Malgun Gothic")

# %%
y = [2, 4, 6, 8]
plt.plot(y)
plt.show()

plt.xticks(fontsize = 20)
plt.plot(y)
plt.show()

# %%
x = [ 1, 2, 3, 4]
y = [ 2, 4, 6, 8]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4]
y = np.array([2, 4, 6, 8])

plt.plot(x, y, ls=":", color = "red", marker = "o")
plt.show()

# %%
os.getcwd()
df = pd.read_csv("./data/20250716/Developer Salary.csv", encoding="euc-kr")

# %%
# 멀티 인덱스
# 성별, 학력, 평균월급
os.getcwd()
os.chdir("../")
#pd.read_csv("Copy Relative Path  : 01_Foundation\python_lib\data\20250716\Developer Salary.csv")

print(r"Copy Path : C:\Users\lgdx\LG_DX_School\01_Foundation\python_lib\data\20250716\Developer Salary.csv")
print(r"Copy Relative Path  : 01_Foundation\python_lib\data\20250716\Developer Salary.csv")
# Out:
# Copy Path : C:\Users\lgdx\LG_DX_School\01_Foundation\python_lib\data\20250716\Developer Salary.csv
# Copy Relative Path  : 01_Foundation\python_lib\data\20250716\Developer Salary.csv

# %%
df
df["월급"] = (df["연봉"] / 12 * 1390).astype(int)
df
# Out:
#            일련번호   나이             학력         성별 정신건강  전문직  개발공부기간  연차  \
# 0          DEV1  <35         Master        Man   No  Dev      15   6
# 1          DEV2  <35  Undergraduate        Man   No  Dev       9   6
# 2          DEV3  >35         Master        Man   No  Dev      26  18
# 3          DEV4  >35  Undergraduate        Man   No  Dev      39  21
# 4          DEV5  <35         Master        Man   No  Dev      19  10
# ...         ...  ...            ...        ...  ...  ...     ...  ..
# 33461  DEV33462  <35         Master        Man  Yes  Dev       7   5
# 33462  DEV33463  <35  Undergraduate        Man   No  Dev       7   2
# 33463  DEV33464  >35  Undergraduate        Man   No  Dev      21  16
# 33464  DEV33465  <35  Undergraduate        Man  Yes  Dev       5   1
# 33465  DEV33466  <35         Master  NonBinary   No  Dev      10   3
#
#                                                       국적      연봉  보유기술개수  \
# ...

# %%
df_select = df[["성별","학력", "월급"]]

display(df_select)
# Out:
#               성별             학력        월급
# 0            Man         Master   8952758
# 1            Man  Undergraduate   5343970
# 2            Man         Master   9015424
# 3            Man  Undergraduate   7935394
# 4            Man         Master   7011970
# ...          ...            ...       ...
# 33461        Man         Master  10888333
# 33462        Man  Undergraduate   4755885
# 33463        Man  Undergraduate  13320833
# 33464        Man  Undergraduate   8108333
# 33465  NonBinary         Master   8731980
#
# [33466 rows x 3 columns]
