# %% [markdown]
# ## 1.SQL 문법
# - SQL 주석처리 : -- (한줄 주석), /* */ (여러줄 주석)
# - SQL문장에서 명령어는 대소문자 구분X
# - 띄어쓰기나 줄바꿈은 명령어에 영향X
# - SQL문장의 끝은 ;(세미콜론)으로 마무리!
# - 실행 CTRL+ENTER, F9
#
# ### 1.1 Query
# - Select문
# ### 1.2.DDL(Data Definition Language)
# - Create, Alter, Drop
# ### 1.3.DML(Data Manipulation Language)
# - Insert, Update, Delete
# ### 1.4.DCL(Data Control Language)
# - Grant, Revoke
# ### 1.5.TCL(Transaction Control Language)
# - Commit, Rollback, Savepoint
#
#
#
# ## 2.자료형
# - ![image.png](attachment:image.png)
#
#
# ## 3.SQL 문장 실행 순서
# - ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 3. Distinct를 사용해서 중복제거.
#
#
# ### 4. alias 사용해서 별칭 설정하기 => Expression 사용하기
# - ![image.png](attachment:image.png)
#
#
#
# ### 5.NULL(NaN) => 연산이 불가능하다.
# - ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Where 절
#
# - ![image.png](attachment:image.png)

# %% [markdown]
# # 산술연산자
# - ![image.png](attachment:image.png)
#
# # 비교연산자
# - ![image-2.png](attachment:image-2.png)
