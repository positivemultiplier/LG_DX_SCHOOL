# %%
# selenium 패키지의 webdriver 모듈을 wd라는 이름으로 import
# By, Keys 모듈을 각각 By, Keys라는 이름으로 import
from selenium import webdriver as wd
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
#1. 크롬 브라우저 실행
driver = wd.Chrome()

# %%
#2. 네이버사이트로 이동
driver.get("https://www.naver.com")

# %%
# 3. 검색창에 "태풍" 검색 후, 엔터치기
search = driver.find_element(By.CSS_SELECTOR,"#query")
search.send_keys("태풍")
search.send_keys(Keys.ENTER)

# %%
# 4. 네비게이션바에서 뉴스 클릭하기 => anchor 태그를 찾아서 클릭해야한다. 
btn = driver.find_element(By.CSS_SELECTOR,"#lnb > div.lnb_group > div > div.lnb_nav_area._nav_area_root > div > div.api_flicking_wrap._conveyer_root > div:nth-child(8) > a")
btn.click()

# %%
# 6. 뉴스제목만 추출 후, 컨텐츠만 출력해보기 
#fdr-96afdd69af484b2284889f3f9d215da6 > div > div > div > div:nth-child(1) > div.sds-comps-base-layout.sds-comps-full-layout.j0ZmtUURh3xcbwC9nntE > div > a.Q4Y2t_v6TP0bwxdR9avD.CL8ortS8q0ByUMOIzqrc > span
title = driver.find_elements(By.CSS_SELECTOR,"#fdr-83e079b4a93a498ab1aee80d0fce01e5 > div > div > div > div > div.sds-comps-base-layout.sds-comps-full-layout.j0ZmtUURh3xcbwC9nntE > div > a.Q4Y2t_v6TP0bwxdR9avD.CL8ortS8q0ByUMOIzqrc > span")
for i in title :
    print(i.text)

# %%
# 6.스크롤 내리기 => 비동기라 body를 다시 찾을 필요가 없다. 
body = driver.find_element(By.CSS_SELECTOR,"body")

for i in range(100):
    body.send_keys(Keys.END)

# %%
title = driver.find_elements(By.CSS_SELECTOR, "div > div > div > div > div.sds-comps-base-layout.sds-comps-full-layout.j0ZmtUURh3xcbwC9nntE > div > a.Q4Y2t_v6TP0bwxdR9avD.CL8ortS8q0ByUMOIzqrc > span ")
for i in title:
    print(i.text)
# Out:
# 탬파베이 매각, '태풍에 날아간' 경기장도 옮길까
# 한일 기상청, 6호 태풍 위파 발생 임박 예보 시작 "홍콩행"
# '공천개입 핵심' 윤상현 수사…'정치권 태풍' 부르나
# 태풍 '나리', 내일 일본 홋카이도 상륙 가능성
# 지구촌 휩쓰는 산불·태풍에 ‘재난 채권’도 기록적 판매
# 한화 1위 태풍 이끈 김경문, 감독들의 무덤서 1000승 신화 쏜다…KBO 후반...
# 거제 242mm 폭우‥태풍급 강풍도 예보
# 태풍 영향권 들어간 일본, 후쿠시마 원전 오염수 13차 방류
# [날씨] 내일(17일) 제6호 태풍 위파 발생 전망…우리나라 영향은?
# KB손해보험, 태풍·집중호우 대비 '비상대응 프로세스' 가동
# [수원 소식] 태풍 대비 대형 노후 가로수 정밀 진단
# [날씨] 내일(17일) 제6호 태풍 위파 발생 전망…우리나라 영향은?
# KB손해보험, 태풍·집중호우 대비 '비상대응 프로세스' 가동
# '메스를 든 사냥꾼' 박용우 "작품 3탕+태풍·우박 촬영…아쉬움 남아" [...
# KB손해보험, 여름철 집중호우·태풍 대비 강화
# 태풍이 되지 못한 공기 덩어리, 밤사이 영남에 비 퍼부어
# 5호 태풍 나리, 일본 삿포로서 소멸…올해 지진 보니
# 5호 태풍 '나리' 日 삿포로 강타…우리나라 영향은?
# 수원시, 하절기 태풍 대비 위해 건축공사장 타워크레인 점검
# [수원시정 AM] 민생회복 소비쿠폰 TF 구성…원활한 신청 유도 등
# 수원시, 태풍 대비 타워크레인 설치 건축공사장 점검
# 극한폭염 이어 폭우의 한주…'태풍 씨앗' 북상, 시간당 최대 50㎜
# “돌풍에서 태풍으로” 15세 당구천재 김현우, 김행직마저 꺾고 8강 진출...
# 창원시, 태풍 등 재난 대비 진해항 모래선박 특별점검
# 산림청, 태풍·호우 대비 전국 가로수 안전점검 실시
# 산림청, 풍수해 대비 가로수 집중 점검…태풍 대비 강화
# 극한폭염 이어 극한호우… 태풍 '씨앗' 북상, 남부 '최대 150㎜' 물폭탄
# 해마다 태풍 상륙…콘크리트 보(洑) 가동보 전면 도입해야
# 5호 태풍 나리 일본 해안선 훑으며 북상...국내 영향은?
# 제주 남쪽 지나는 '태풍 씨앗'…태풍급 비바람 주의
# 남부 쏟아진 물폭탄, 동해안으로…태풍 못된 열대저압부의 ‘뒤끝’
# 한반도 코앞에서 태풍 발달?…13~14일 제주·남부 폭우 주의
# 지역별 오늘의 날씨, 내일과 모레 서쪽 지역 중심 매우 강하고 많은 비...
# 5호 태풍 '나리', 日 도쿄 부근서 발생 예정…한반도 영향은
# [경기광주소식]시, 어린이집 급식·위생·안전 점검 등
# "누구나 알기 쉽게"…소방청, '현장 중심' 장비 명칭 개선
# '태풍 다나스 관통' 대만서 2명 사망·500여명 부상
# 한전KPS, 태풍·폭염·기상이변 대비 신속복구체계 상시 가동
# KGM, 수해 차량 및 여름휴가 대비 차량 무상점검 캠페인
# 산업부, '태풍·집중호우 대비' LNG 생산기지 안전점검
# 창원특례시, 태풍 등 재난 대비 진해항 모래선박 특별점검
# 김천시, 집중호우·태풍 대비 도로 빗물받이 일제정비
# 태풍에 비행기 못 떴는데 '숙박취소' 거절…8월 제주 여행 '소비자 주의...
# 5호 태풍 나리 수명은 이틀, 11호 열대저압부는 태풍 발달 없이 약화
# 5호 태풍 나리, 일본 도쿄→삿포로 이동 예정…예상 경로 보니
# LH 경남본부, 태풍 및 혹서기 대비 안전문화행사
# '소는 잃었지만 외양간은 고친 포항시' 2년 연속 재난관리평가 우수 등...
# 한미일 기상청, 열대저압부a→5호 태풍 나리 발달 예상 경로 발표
# 최대 200㎜ 이상 폭우...16개 시도 산사태 위기경보 '주의' 상향
# 제5호 태풍 '나리' 예상 진로는?
# “시민 안전이 최우선” 당진시, 여름철 재해 예방 현장점검
# 타이완 할퀸 태풍에 중국 긴장...찜통 더위에 열사병 속출
# 수원시, 태풍 대비 대형 노후 가로수 정밀 안전진단
# 양평군, 여름철 호우·태풍 대비…"피해 복구 도상훈련 실시"
# [2025년 태풍 예상]6호 태풍 위파 이어 발생하는 7호 태풍 프란시스코,8...
# [속보] 퇴근길 서울 전역 호우주의보 발령
# ‘불볕더위’ 낮 최고 35도…태풍 '씨앗'영향? 남부 100mm폭우[오늘날씨...
# '태풍의 눈'에 들어온 달러-원…변동성 유발 요인은
# 말레이시아 총리 "美 관세위협, 1회성 태풍 아니라 새 일상"
# 2025년 6호 태풍 위파 정보 등 오늘의 날씨 및 내일날씨,,내일 중부지방...
# 나주시, 금성산 생태물놀이장 오는 26일 개장
# 자연재해위험개선지구 정비 지지부진…주민 불안
# [광주소식]동구, 하계 재난 대비 위험 건축물 190곳 점검 등
# 한반도 코앞에서 태풍?…열대저압부 북상 남부 호우
# 4호 태풍 '다나스' 대만 관통하며 '물폭탄'…이동 경로 보니
# 양천구, 태풍 대비 가로수 안전진단 강화
# 사과·배 생육 양호.. 태풍·햇볕데임 우려는 여전
# 네이버 날씨, '제보 지도' 추가…재해재난 피해 최소화
# 태풍 씨앗 '열대저압부' 발생..제주 남부 해상 지날 듯
# 중국도 폭염에 실신·사망…태풍 수증기에 찜통더위 ‘푹푹’
# 고압선 튀고 천막 붙들고…타이완 강타한 태풍 '다나스'
# 날씨, 전국 80mm 비소식 "태풍 전단계 영향때문" 서울·대구 35도 폭염
# [지식채널e] 태풍 뚫고, 심해까지? 한국 해양조사선의 충격적 진화
# 제5호 태풍 '나리', 북동진하며 온대저기압으로 약화 예상
# 보령해경, 여름철 해양오염 예방 '어선·예인선' 집중 단속
# 태풍 못 된 열대저압부에 한동안 비…30도 안팎으로 무더위 숙져
# [보푸라기]폭염에 태풍까지…보험사, 기후이변 대응 필요한 이유는
# 중국, 태풍 ‘다나스’에 쇼핑몰 천장 무너져 물폭탄
# 자연재해위험개선지구 정비 지지부진…주민 불안
# [제주날씨]열대저압부 덕에 폭염 기세 꺽여..태풍 발달 못하고 오늘밤 ...
# 부산날씨 "최대 150mm 많은비" 태풍 전단계 북상중
# 경주시, 재난대응 체계 가동…"폭염·태풍 피해 예방"
# 중국 향하는 4호 태풍 다나스… '폭염' 한반도 더 뜨거워 진다
# 4호 태풍 ‘다나스’…한반도 폭염 더 심해질 듯
# 전봇대 도미노처럼 '와르르'…태풍 덮친 라스베이거스(영상)
# 日참의원 선거서 與과반유지 불투명…보수강세 지역구서도 고전
# 40도 폭염 속 쏟아진 태풍급 폭우…줄줄이 뿌리째 뽑힌 가로수
# 2025년 5호 태풍 나리 일본 삿포로 강타...지역별 오늘의 날씨 및 내일날...
# 5호 태풍 나리, 일본 도쿄 발생…예상 이동 경로 보니
# [단독] 9월 이후 잦은 태풍... ‘가을 우기’ 생겼다
# 태풍 '다나스'가 폭염 강화…서울 화요일 36도
# 서울·대전 낮 최고 36도 서쪽기온↑…中향하는 태풍 간접영향 [내일날...
# 일본 향하는 5호 태풍 '나리'…72시간 내 온대저기압으로 약화
# [영상] 침수로 꿈쩍 않는 출입문…실제 상황이라면 어떻게?
# 전남 목포시, 여름철 자연재난 대비 긴급 점검회의…현장 대응 강화
# 철제 구조물 무너지고 차량도 떠밀려…태풍 다나스, 대만 강타
# 예산군, 올해 하반기 위험수목 처리 지원사업 시행
# 에어부산 화재 항공기, 조사 종료 후 해체 착수…“태풍 전도 우려”
# 에어부산 화재 여객기, 김해공항서 뺀다…"태풍 시 사고 우려"
# 강풍·태풍도 없었는데…속초 시내 신호등이 기울어진 까닭은
# 日후쿠시마 원전 오염수 13차 방류 시작…다음 달 1일까지 7800t
# 대만에 200mm '물폭탄' 뿌린 4호 태풍 '다나스'…국내 영향은?
# 양평군, 여름철 호우·태풍 대비…"피해 복구 도상훈련 실시"
# [2025년 태풍 예상]6호 태풍 위파 이어 발생하는 7호 태풍 프란시스코,8...
# "침수 피해 최소화 총력"…KB손보, 여름철 '비상대응 프로세스' 가동
# [속보] 퇴근길 서울 전역 호우주의보 발령
# KGM, 수해 차량 수리비 40% 할인한다
# ‘불볕더위’ 낮 최고 35도…태풍 '씨앗'영향? 남부 100mm폭우[오늘날씨...
# 극한 기후 속 '재난 채권' 판매액 사상 최대
# '태풍의 눈'에 들어온 달러-원…변동성 유발 요인은
# '태풍의 눈'에 들어온 달러-원…변동성 유발 요인은
# 말레이시아 총리 "美 관세위협, 1회성 태풍 아니라 새 일상"
# 2025년 6호 태풍 위파 정보 등 오늘의 날씨 및 내일날씨,,내일 중부지방...
# 나주시, 금성산 생태물놀이장 오는 26일 개장
# 제4호 태풍 '다나스' 대만 직격…2명 사망·500여명 부상
# KB손보, 여름철 집중호우 대비 ‘비상대응 프로세스’ 가동
# "장맛비 쏟아진다"… '비상대응 프로세스' 돌리는 KB손보의 24시
# 자연재해위험개선지구 정비 지지부진…주민 불안
# 5호 태풍 나리, 일본 강타한다…한반도 영향은
# KGM, 수해 차량 특별 서비스 캠페인
# ‘태풍 다나스 관통’ 대만에서 2명 사망·500여명 부상
# KGM, 수해 차량 및 여름휴가 대비 차량 무상점검 캠페인 실시
# [광주소식]동구, 하계 재난 대비 위험 건축물 190곳 점검 등
# 한반도 코앞에서 태풍?…열대저압부 북상 남부 호우
# 제주 남쪽 지나는 '태풍 씨앗'…곳곳에 태풍급 강풍
# 4호 태풍 '다나스' 대만 관통하며 '물폭탄'…이동 경로 보니
# 양천구, 태풍 대비 가로수 안전진단 강화
# KB손해보험, 여름철 집중호우 대비 '비상대응 프로세스' 가동
# 사과·배 생육 양호.. 태풍·햇볕데임 우려는 여전
# 네이버 날씨, '제보 지도' 추가…재해재난 피해 최소화
# 네이버 날씨, '제보 지도' 추가…재해재난 피해 최소화
# 산업부, 태풍·집중호우 대비 LNG 생산기지 안전점검
# KB손보, 집중호우 대비 ‘비상대응 프로세스’ 가동
# 日 후쿠시마 원전 오염수 13차 방류 시작…방류량 7천800톤
# 태풍 씨앗 '열대저압부' 발생..제주 남부 해상 지날 듯
# ‘고객에 진심’ KGM, 수해 차량 수리비 40% 할인
# 중국도 폭염에 실신·사망…태풍 수증기에 찜통더위 ‘푹푹’
# 고압선 튀고 천막 붙들고…타이완 강타한 태풍 '다나스'
# 날씨, 전국 80mm 비소식 "태풍 전단계 영향때문" 서울·대구 35도 폭염
# [지식채널e] 태풍 뚫고, 심해까지? 한국 해양조사선의 충격적 진화

# %% [markdown]
# ## 선택자를 복사할때 최근 기법
# - 복사한 선택자에 의미를 알 수 없는 난수의 id난 class가 존재
# - 대규모의 포털에서 사용하는 정책
# - 난수가 포함된 아이디(#)는 지워버리자.
# - 클래스(.)는 지우지 말고, 의미있는 클래스만 남기자.

# %%
# 링크 수집 Selenium
# 한솥도시락(사람처럼 코딩하는 방법, 오류가 났을 때 대처하는 방법)
