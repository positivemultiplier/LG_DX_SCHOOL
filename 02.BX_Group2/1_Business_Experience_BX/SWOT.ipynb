# %% [markdown]
# # 1.위기(SWOT:Weekness) => IFRS 기준으로한 LG그룹의 재무제표와 LG전자의 재무제표, Division별 재무제표 분석을 통해서 분석
# ## LG전자 사업부 (5Division)
# - Home Appliance & Air Solution 부문에서의 경쟁력 약화
#     - 각부서의 매출, 영업이익, 시장점유율 감소
# - Home Entertainment Solution 부문에서의 경쟁력 약화
#     - 각부서의 매출, 영업이익, 시장점유율 감소
# - Vehicle component Solutions 부문에서의 경쟁력 약화
#     - 각부서의 매출, 영업이익, 시장점유율 감소
# - Business Solutions 부문에서의 경쟁력 약화
#     - 각부서의 매출, 영업이익, 시장점유율 감소
# - 기타 부문에서의 경쟁력 약화
#
#
# - LG전자의 매출과 영업이익이 정체되어있다.
# - 새로운성장동력이 필요하다.

# %% [markdown]
# # 2.기회(SWOT:Opportunity) => 통계청 Data, Data.go.kr, crawling, LG 경제연구원등의 각종 보고서, 논문들을 통해서 분석
# ## Pet 인구의 증가
# - Pet 인구의 증가로 인해 Pet 관련 제품 및 서비스에 대한 수요 증가
# ## Pet 관련 시장의 성장
# - Pet 관련 시장의 지속적인 성장으로 인해 새로운 사업 기회 창출 가능성
# ## pet 인구의 소비패턴 파악
# - Pet을 위해서 기꺼이 소비한다.
# ## Pet healthcare 시장의 가능성
# - pet 애견인의 관심사는 pet의 건강에 대한 관심 증가
# ## pet Market Report들이 많아지고 있다.(논리적 근거)
# - 각종 매체와 논문에서 Blue Ocean Strategy를 찾을 수 있다.
# ## Python과 library등을 사용하여 우리의 데이터 수집과정등을 보여줄 수 있다.

# %% [markdown]
# # 3.강점(SWOT:Strong) => LG전자의 기술력, 제품군, 브랜드 파워 등을 통해서 분석
# ## LG전자의 기술력
# - 케이지는 제약사항이 많다: 각 항공사마다 5~7 kg의 무게 제한이 있다.
# - 케이지의 digital sensor 기술은 LG의 강점이다.
# - LG Rollable OLED 기술은 LG의 강점이다.
# - LG는 premium 브랜드가 되고 싶은 needs가 있다.
# ## LG전자의 방향 (with Pet)
# - with pet 관련 제품군들이 있다.
# - LG hello 등에서 pet care 제품군이 있다.
# - 추가적으로 우리의 제안이 LG전자의 방향과 일치한다.

# %% [markdown]
# # 4.약점(SWOT:Weekness) => 설문조사를 통해서 statistical한 분석을 통해서 분석(회귀분석등)
# - LG전자가 들어가기에는 시장이 작다. 약 10조규모 20조 규모로 성장가능성 불확실
# - 값싼 제품들이 경쟁자로 빠르게 등장할 가능성이 있다.
# - LG 전자의 premium 전략이 일반인들을 대상으로 하지 않기때문에 보편적이 아닐 수 있다.

# %%
0	매출	88	0.976367
1	시장	64	0.710085
2	사업	54	0.599135
3	전기차	42	0.465994
4	제품	37	0.410518
5	영업이익	34	0.377233
6	실적	32	0.355043
7	LG전자	30	0.332853
8	박원재	30	0.332853
9	이어서	30	0.332853
10	이상입니다	30	0.332853
11	분은	28	0.310662
12	주요	27	0.299567
13	글로벌	27	0.299567
14	다음으로	27	0.299567
15	성장	26	0.288472
16	수익성	26	0.288472
17	전망에	26	0.288472
18	전망	24	0.266282
19	따른	24	0.266282
